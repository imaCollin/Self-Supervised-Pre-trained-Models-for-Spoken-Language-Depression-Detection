# %% [markdown]
# # Parameters

# %%
# 配置文件
config = {
    "learning_rate": 0.001,
    "batch_size": 32,
    "num_epochs": 20,
    "data_path": "./data",
    "model_save_path": "./models/saved_model.pth"
}
